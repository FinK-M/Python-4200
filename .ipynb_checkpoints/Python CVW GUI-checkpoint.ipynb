# %% [markdown]
# Python CVW GUI
# =======

# %% [markdown]
# This notebook serves as a GUI front end for the Python 4200 Library.
#
# Run the cell below to import all the necessary dependencies.

# %%
# %matplotlib inline
from libs import ipynb4200
ipynb4200.boot_GUI()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _handle_msg(self, msg)
#     347             if 'sync_data' in data:
#     348                 sync_data = data['sync_data']
# --> 349                 self.set_state(sync_data) # handles all methods
#     350
#     351         # Handle a state request.
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in set_state(self, sync_data)
#     251                 from_json = self.trait_metadata(name, 'from_json', self._trait_from_json)
#     252                 with self._lock_property(name, json_value):
# --> 253                     setattr(self, name, from_json(json_value))
#     254
#     255     def send(self, content):
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget_selection.py in _selected_label_changed(self, name, old, new)
#     134         if self.value_lock.acquire(False):
#     135             try:
# --> 136                 self.value = self._options_dict[new]
#     137             finally:
#     138                 self.value_lock.release()
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\interaction.py in call_f(name, old, new)
#     211         container.kwargs = {}
#     212         for widget in kwargs_widgets:
# --> 213             value = widget.value
#     214             container.kwargs[widget._kwarg] = value
#     215         if co:
#
# AttributeError: 'Tab' object has no attribute 'value'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _handle_msg(self, msg)
#     347             if 'sync_data' in data:
#     348                 sync_data = data['sync_data']
# --> 349                 self.set_state(sync_data) # handles all methods
#     350
#     351         # Handle a state request.
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in set_state(self, sync_data)
#     251                 from_json = self.trait_metadata(name, 'from_json', self._trait_from_json)
#     252                 with self._lock_property(name, json_value):
# --> 253                     setattr(self, name, from_json(json_value))
#     254
#     255     def send(self, content):
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget_selection.py in _selected_label_changed(self, name, old, new)
#     134         if self.value_lock.acquire(False):
#     135             try:
# --> 136                 self.value = self._options_dict[new]
#     137             finally:
#     138                 self.value_lock.release()
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\interaction.py in call_f(name, old, new)
#     211         container.kwargs = {}
#     212         for widget in kwargs_widgets:
# --> 213             value = widget.value
#     214             container.kwargs[widget._kwarg] = value
#     215         if co:
#
# AttributeError: 'Tab' object has no attribute 'value'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _handle_msg(self, msg)
#     347             if 'sync_data' in data:
#     348                 sync_data = data['sync_data']
# --> 349                 self.set_state(sync_data) # handles all methods
#     350
#     351         # Handle a state request.
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in set_state(self, sync_data)
#     251                 from_json = self.trait_metadata(name, 'from_json', self._trait_from_json)
#     252                 with self._lock_property(name, json_value):
# --> 253                     setattr(self, name, from_json(json_value))
#     254
#     255     def send(self, content):
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget_selection.py in _selected_label_changed(self, name, old, new)
#     134         if self.value_lock.acquire(False):
#     135             try:
# --> 136                 self.value = self._options_dict[new]
#     137             finally:
#     138                 self.value_lock.release()
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\interaction.py in call_f(name, old, new)
#     211         container.kwargs = {}
#     212         for widget in kwargs_widgets:
# --> 213             value = widget.value
#     214             container.kwargs[widget._kwarg] = value
#     215         if co:
#
# AttributeError: 'Tab' object has no attribute 'value'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _handle_msg(self, msg)
#     347             if 'sync_data' in data:
#     348                 sync_data = data['sync_data']
# --> 349                 self.set_state(sync_data) # handles all methods
#     350
#     351         # Handle a state request.
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in set_state(self, sync_data)
#     251                 from_json = self.trait_metadata(name, 'from_json', self._trait_from_json)
#     252                 with self._lock_property(name, json_value):
# --> 253                     setattr(self, name, from_json(json_value))
#     254
#     255     def send(self, content):
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget_selection.py in _selected_label_changed(self, name, old, new)
#     134         if self.value_lock.acquire(False):
#     135             try:
# --> 136                 self.value = self._options_dict[new]
#     137             finally:
#     138                 self.value_lock.release()
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\interaction.py in call_f(name, old, new)
#     211         container.kwargs = {}
#     212         for widget in kwargs_widgets:
# --> 213             value = widget.value
#     214             container.kwargs[widget._kwarg] = value
#     215         if co:
#
# AttributeError: 'Tab' object has no attribute 'value'
