# %% [markdown]
# [Index](Index.ipynb) - [Back](Widget Basics.ipynb) - [Next](Widget Events.ipynb)

# %% [markdown]
# # Widget List

# %% [markdown]
# ## Complete list

# %% [markdown]
# For a complete list of the widgets available to you, you can list the classes in the widget namespace (as seen below).  `Widget` and `DOMWidget`, not listed below, are base classes.

# %%
from IPython.html import widgets
[n for n in dir(widgets) if not n.endswith('Widget') and n[0] == n[0].upper() and not n[0] == '_']
# Out:
# ['Accordion',
#  'BoundedFloatText',
#  'BoundedIntText',
#  'Box',
#  'Button',
#  'CallbackDispatcher',
#  'Checkbox',
#  'Dropdown',
#  'FlexBox',
#  'FloatProgress',
#  'FloatRangeSlider',
#  'FloatSlider',
#  'FloatText',
#  'HBox',
#  'HTML',
#  'Image',
#  'IntProgress',
#  'IntRangeSlider',
#  'IntSlider',
#  'IntText',
#  'Latex',
#  'Output',
#  'RadioButtons',
#  'Select',
#  'SelectMultiple',
#  'Tab',
#  'Text',
#  'Textarea',
#  'ToggleButton',
#  'ToggleButtons',
#  'VBox']

# %% [markdown]
# ## Numeric widgets

# %% [markdown]
# There are 8 widgets distributed with IPython that are designed to display numeric values.  Widgets exist for displaying integers and floats, both bounded and unbounded.  The integer widgets share a similar naming scheme to their floating point counterparts.  By replacing `Float` with `Int` in the widget name, you can find the Integer equivalent.

# %% [markdown]
# ### FloatSlider

# %%
widgets.FloatSlider(
    value=7.5,
    min=5.0,
    max=10.0,
    step=0.1,
    description='Test:',
)

# %% [markdown]
# Sliders can also be **displayed vertically**.

# %%
widgets.FloatSlider(
    value=7.5,
    min=5.0,
    max=10.0,
    step=0.1,
    description='Test',
    orientation='vertical',
)

# %% [markdown]
# ### FloatProgress

# %%
widgets.FloatProgress(
    value=7.5,
    min=5.0,
    max=10.0,
    step=0.1,
    description='Loading:',
)

# %% [markdown]
# ### BoundedFloatText

# %%
widgets.BoundedFloatText(
    value=7.5,
    min=5.0,
    max=10.0,
    description='Text:',
)

# %% [markdown]
# ### FloatText

# %%
widgets.FloatText(
    value=7.5,
    description='Any:',
)

# %% [markdown]
# ## Boolean widgets

# %% [markdown]
# There are two widgets that are designed to display a boolean value.

# %% [markdown]
# ### ToggleButton

# %%
widgets.ToggleButton(
    description='Click me',
    value=False,
)

# %% [markdown]
# ### Checkbox

# %%
widgets.Checkbox(
    description='Check me',
    value=True,
)

# %% [markdown]
# ## Selection widgets

# %% [markdown]
# There are four widgets that can be used to display single selection lists.  All four inherit from the same base class.  You can specify the **enumeration of selectables by passing a list**.  You can **also specify the enumeration as a dictionary**, in which case the **keys will be used as the item displayed** in the list and the corresponding **value will be returned** when an item is selected.

# %% [markdown]
# ### Dropdown

# %%
from IPython.display import display
w = widgets.Dropdown(
    options=["1", "2", "3"],
    description='Number:',
)
display(w)

# %%
w.value
# Out:
# '1'

# %% [markdown]
# The following is also valid:

# %%
w = widgets.Dropdown(
    values={'One': 1, 'Two': 2, 'Three': 3},
    value=2,
    description='Number:',
)
display(w)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-75b84678d619> in <module>()
#       2     values={'One': 1, 'Two': 2, 'Three': 3},
#       3     value=2,
# ----> 4     description='Number:',
#       5 )
#       6 display(w)
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget_selection.py in __init__(self, *args, **kwargs)
#      66         if 'options' in kwargs:
#      67             self.options = kwargs.pop('options')
# ---> 68         DOMWidget.__init__(self, *args, **kwargs)
#      69         self._value_in_options()
#      70
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in __init__(self, *pargs, **kwargs)
#     479
#     480     def __init__(self, *pargs, **kwargs):
# --> 481         super(DOMWidget, self).__init__(*pargs, **kwargs)
#     482
#     483         def _validate_border(name, old, new):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in __init__(self, **kwargs)
#     151         """Public constructor"""
#     152         self._model_id = kwargs.pop('model_id', None)
# --> 153         super(Widget, self).__init__(**kwargs)
#     154
#     155         Widget._call_widget_constructed(self)
#
# C:\Anaconda3\lib\site-packages\IPython\config\configurable.py in __init__(self, **kwargs)
#      84         # This should go second so individual keyword arguments override
#      85         # the values in config.
# ---> 86         super(Configurable, self).__init__(**kwargs)
#      87
#      88     #-------------------------------------------------------------------------
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __init__(self, *args, **kw)
#     563         # notifications.
#     564         for key, value in iteritems(kw):
# --> 565             setattr(self, key, value)
#     566
#     567     def _notify_trait(self, name, old_value, new_value):
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in __set__(self, obj, value)
#     443             # we explicitly compare silent to True just in case the equality
#     444             # comparison above returns something other than True/False
# --> 445             obj._notify_trait(self.name, old_value, new_value)
#     446
#     447     def _validate(self, obj, value):
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget.py in _notify_trait(self, name, old_value, new_value)
#     371         # registered validation to be processed prior to allowing the widget
#     372         # machinery to handle the state.
# --> 373         LoggingConfigurable._notify_trait(self, name, old_value, new_value)
#     374
#     375         # Send the state after the user registered callbacks for trait changes
#
# C:\Anaconda3\lib\site-packages\IPython\utils\traitlets.py in _notify_trait(self, name, old_value, new_value)
#     600                     c(name, new_value)
#     601                 elif nargs + offset == 3:
# --> 602                     c(name, old_value, new_value)
#     603                 else:
#     604                     raise TraitError('a trait changed callback '
#
# C:\Anaconda3\lib\site-packages\IPython\html\widgets\widget_selection.py in _value_changed(self, name, old, new)
#     126                 # undo the change, and raise KeyError
#     127                 self.value = old
# --> 128                 raise KeyError(new)
#     129             finally:
#     130                 self.value_lock.release()
#
# KeyError: 2

# %%
w.value
# Out:
# '1'

# %% [markdown]
# ### RadioButtons

# %%
widgets.RadioButtons(
    description='Pizza topping:',
    values=['pepperoni', 'pineapple', 'anchovies'],
)

# %% [markdown]
# ### Select

# %%
widgets.Select(
    description='OS:',
    values=['Linux', 'Windows', 'OSX'],
)

# %% [markdown]
# ### ToggleButtons

# %%
widgets.ToggleButtons(
    description='Speed:',
    values=['Slow', 'Regular', 'Fast'],
)

# %% [markdown]
# ## String widgets

# %% [markdown]
# There are 4 widgets that can be used to display a string value.  Of those, the **`Text` and `Textarea` widgets accept input**.  The **`Latex` and `HTML` widgets display the string** as either Latex or HTML respectively, but **do not accept input**.

# %% [markdown]
# ### Text

# %%
widgets.Text(
    description='String:',
    value='Hello World',
)

# %% [markdown]
# ### Textarea

# %%
widgets.Textarea(
    description='String:',
    value='Hello World',
)

# %% [markdown]
# ### Latex

# %%
widgets.Latex(
    value="$$\\frac{n!}{k!(n-k)!} = \\binom{n}{k}$$",
)

# %% [markdown]
# ### HTML

# %%
widgets.HTML(
    value="Hello <b>World</b>"
)

# %% [markdown]
# ## Button

# %%
widgets.Button(description='Click me')

# %% [markdown]
# [Index](Index.ipynb) - [Back](Widget Basics.ipynb) - [Next](Widget Events.ipynb)
